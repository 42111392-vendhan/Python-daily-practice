# %% [markdown]
# ### **pattern**

# %%
row = int(input("Enter the number of rows: "))
symbol = input("Enter the symbol to print: ")

for x in range(row):
    for y in range(0,x+1):
        print(symbol, end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
