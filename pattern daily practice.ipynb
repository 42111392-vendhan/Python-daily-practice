# %% [markdown]
# ### **Pattern**

# %%
def pattern(n):
    for x in range(1,n+1):
        for y in range(x):
            print(x, end="")
        print()
pattern(9)
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999
