# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a= "1234"
x= a.isdigit()
print(x)
# Out:
# True

# %%
a= "hellonjhyte1234"
x= a.isalnum()
print(x)
# Out:
# True

# %%
a= "hellonjhyt"
x= a.isalpha()
print(x)
# Out:
# True

# %%
a= "hellonjhyte1234"
x= a.islower()
print(x)
# Out:
# True

# %%
a= "Tellonjhyte1234"
x= a.isupper()
print(x)
# Out:
# False

# %%
a= "hellonjhyte1234"
x= a.upper()
print(x)
# Out:
# HELLONJHYTE1234

# %%
a= "hellonASFDte1234"
x= a.lower()
print(x)
# Out:
# hellonasfdte1234

# %%
a= "hellonjhyte1234.pdf"
x= a.endswith(".pdf")
print(x)
# Out:
# True

# %%
mylist = ["apple.py", "banana.txt", "cherry.pdf", "date.docx"]

for a in mylist:
    if a.endswith(".docx"):
        print(a)
# Out:
# date.docx

# %%
mylist = ["apple.py", "banana.txt", "cherry.pdf", "date.docx"]

for a in mylist:
    if a.startswith("b"):
        print(a)
# Out:
# banana.txt

# %%
a="Weee udjddn"
x= a.title()
print(x)
# Out:
# Weee Udjddn

# %%
a="Weee udjddn"
x= a.capitalize()
print(x)
# Out:
# Weee udjddn

# %%
a="Weee udjddn"
x= a.swapcase()
print(x)
# Out:
# wEEE UDJDDN

# %%
a="Weee udjd dn"
x= a.split()
print(x)
# Out:
# ['Weee', 'udjd', 'dn']

# %%
a="dWeeedudjddnd"
x= a.split("d")
print(x)
# Out:
# ['', 'Weee', 'u', 'j', '', 'n', '']

# %%
a=["Weee", "udjd", "dn"]
x= " ".join(a)
print(x)
# Out:
# Weee udjd dn

# %%
def star_pattern(n):
    for x in range(n, 0, -1):
        for y in range(x):
            print("#",end=" ")
        print()
star_pattern(5)
# Out:
# # # # # #
# # # # #
# # # #
# # #
# #
