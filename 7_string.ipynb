# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a= "1234"
x= a.isdigit()
print(x)
# Out:
# True

# %%
a= "hellonjhyte1234"
x= a.isalnum()
print(x)
# Out:
# True

# %%
a= "hellonjhyt"
x= a.isalpha()
print(x)
# Out:
# True

# %%
a= "hellonjhyte1234"
x= a.islower()
print(x)
# Out:
# True

# %%
a= "Tellonjhyte1234"
x= a.isupper()
print(x)
# Out:
# False

# %%
a= "hellonjhyte1234"
x= a.upper()
print(x)
# Out:
# HELLONJHYTE1234

# %%
a= "hellonASFDte1234"
x= a.lower()
print(x)
# Out:
# hellonasfdte1234

# %%
a= "hellonjhyte1234.pdf"
x= a.endswith(".pdf")
print(x)
# Out:
# True

# %%
mylist = ["apple.py", "banana.txt", "cherry.pdf", "date.docx"]

for a in mylist:
    if a.endswith(".docx"):
        print(a)
# Out:
# date.docx

# %%
mylist = ["apple.py", "banana.txt", "cherry.pdf", "date.docx"]

for a in mylist:
    if a.startswith("b"):
        print(a)
# Out:
# banana.txt

# %%
a="Weee udjddn"
x= a.title()
print(x)
# Out:
# Weee Udjddn

# %%
a="Weee udjddn"
x= a.capitalize()
print(x)
# Out:
# Weee udjddn

# %%
a="Weee udjddn"
x= a.swapcase()
print(x)
# Out:
# wEEE UDJDDN

# %%
a="Weee udjd dn"
x= a.split()
print(x)
# Out:
# ['Weee', 'udjd', 'dn']

# %%
a="dWeeedudjddnd"
x= a.split("d")
print(x)
# Out:
# ['', 'Weee', 'u', 'j', '', 'n', '']

# %%
a=["Weee", "udjd", "dn"]
x= " ".join(a)
print(x)
# Out:
# Weee udjd dn

# %%
def star_pattern(n):
    for x in range(n, 0, -1):
        for y in range(x):
            print("#",end=" ")
        print()
star_pattern(5)
# Out:
# # # # # #
# # # # #
# # # #
# # #
# #

# %% [markdown]
# ### **replace()**

# %%
a = "the quick brown fox jumps over the lazy dog"

x= a.replace("fox", "cat")
print(x)
# Out:
# the quick brown cat jumps over the lazy dog

# %% [markdown]
# ### **count()**

# %%
a = "the quick brown fox jumps over the lazy dog"

x= a.count("q")
print(x)
# Out:
# 1

# %% [markdown]
# ### **find()**

# %%
a = "the quick queen"
x=a.find("q")
print(x)
# Out:
# 4

# %% [markdown]
# ### **index()**

# %%
a = "the quick queen"
x=a.index("q")
print(x)
# Out:
# 4

# %% [markdown]
# ### **format()**

# %%
name = "John Doe"
print("My name is {}".format(name))
# Out:
# My name is John Doe

# %%
name = "John Doe"
city = "New York"
country = "USA"

print("hello i\'am {}, from {},{}".format(name, city, country))
# Out:
# hello i'am John Doe, from New York,USA

# %% [markdown]
# ### **String formatting**
# * %d = integer
# * %s = string
# * %f = float with default 6 decimal places
# * %.2f = float with two decimal places
# * %.10f = float with ten decimal places

# %%
name = "John Doe"
age = 30
height = 1.75
print("%s is %d year old and height is %.3f" %(name, age, height))
# Out:
# John Doe is 30 year old and height is 1.750

# %% [markdown]
# ### **f'string(f format)**

# %%
quantity = 5
itemno = 123
price = 49.95

print(f"I want {quantity} pieces of item number {itemno}, which costs ${price}.")
# Out:
# I want 5 pieces of item number 123, which costs $49.95.
