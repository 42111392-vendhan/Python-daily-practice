# %% [markdown]
# ### **Operators**

# %% [markdown]
# ## *arithmetic operator*

# %%
print(10 + 3) # 13
print(10-3) #  7
print(10 * 3) # 30
print(10 / 3) # 3.333....
print(10 ** 3)# pwo = 10*10*10 = 1000
print(10 // 3)# Q => 3
print(10 % 3) # R => 1

# %% [markdown]
# ## *assignment operator*

# %%
a = 10
print(a)
a += 5 
print(a)
a *= 2 
print(a)
b = 0
b += 20
print(b)
# Out:
# 10
# 15
# 30
# 20

# %% [markdown]
# ## *comparison operator*

# %%
print(10 == 10) 
print(10 != 10) 
print(10 > 10) 
print(10 >= 10) 
print(10 < 10) 
print(10 <= 10)
# Out:
# True
# False
# False
# True
# False
# True

# %% [markdown]
# ## *logical operator*

# %%
print('----AND----')
print(10 == 10 and 6 > 4) 
print(10 != 10 and 6 > 4) 
print(10 == 10 and 6 < 4) 
print(10 != 10 and 6 < 4) 
print('----OR----')
print(10 == 10 or 6 > 4) 
print(10 != 10 or 6 > 4) 
print(10 == 10 or 6 < 4) 
print(10 != 10 or 6 < 4) 
print('----Not----')
print(not 10==10) 
print(not 10!=10)
# Out:
# ----AND----
# True
# False
# False
# False
# ----OR----
# True
# True
# True
# False
# ----Not----
# False
# True

# %% [markdown]
# ### **Python Collection**
# #### **List**
#
# *is a collection which is ordered and changeable.
# Allows duplicate members. Denoted by []*

# %%
mylist = [10,20.55,"Hello",True,10,"Hello",20.55,False,True,10,20.55,True]
print(mylist,type(mylist))
print(mylist[5])
print(mylist[8])
mylist[8]="Welcome"
print(mylist)
# Out:
# [10, 20.55, 'Hello', True, 10, 'Hello', 20.55, False, True, 10, 20.55, True] <class 'list'>
# Hello
# True
# [10, 20.55, 'Hello', True, 10, 'Hello', 20.55, False, 'Welcome', 10, 20.55, True]

# %% [markdown]
# #### **Tuple**
#
# *is a collection which is ordered and unchangeable.
# Allows duplicate members. Denoted by()*

# %%
mytuple = (10,20.55,"Hello",True,10,"Hello",20.55,False,True,10,20.55,True)
print(mytuple,type(mytuple))
print(mytuple[4])
print(mytuple[7])
mytuple[7]="Python"
print(mytuple)
# Out:
# (10, 20.55, 'Hello', True, 10, 'Hello', 20.55, False, True, 10, 20.55, True) <class 'tuple'>
# 10
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       3 print(mytuple[4])
#       4 print(mytuple[7])
# ----> 5 mytuple[7]="Python"
#       6 print(mytuple)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### **Set**
#
# *is a collection which is unordered and unindexed.
# No duplicate members. Denoted by{}*

# %%
myset = {100,"hai",100,"hello","hai",50.55,100,"hello",50.55,True,False}
print(myset,type(myset))
# Out:
# {'hello', True, False, 50.55, 100, 'hai'} <class 'set'>

# %% [markdown]
# #### **Dictionary**
# *is a collection that is unordered, changeable (mutable), and stores
# data in key-value pairs. Keys must be unique (no duplicate keys). It is denoted
# by curly braces {} using the format{key: value}*

# %%
mydict = {
"Name":"Jeevan",
"Course":"Python",
"Age":15,
100:50.55,
40.55:True,
}
print(mydict,type(mydict))

print(mydict["Name"])
mydict["Age"]= 16
mydict["City"]="Chennai"
print(mydict)
# Out:
# {'Name': 'Jeevan', 'Course': 'Python', 'Age': 15, 100: 50.55, 40.55: True} <class 'dict'>
# Jeevan
# {'Name': 'Jeevan', 'Course': 'Python', 'Age': 16, 100: 50.55, 40.55: True, 'City': 'Chennai'}

# %% [markdown]
# ### **Mutable vs Immutable Objects**
# **Immutable** *(int, f loat, bool, str, tuple)*
# * *Same data stores in Same location*
# * *Different Data stores in Different location*

# %%
a = 100
b = 100
c = 101
print(a,type(a),id(a))
print(b,type(b),id(b))
print(c,type(c),id(c))
# Out:
# 100 <class 'int'> 140720575362584
# 100 <class 'int'> 140720575362584
# 101 <class 'int'> 140720575362616

# %%
x = (10,20,30,40,50)
y = (10,20,30,40,50)
print(x,type(x),id(x))
print(y,type(y),id(y))
# Out:
# (10, 20, 30, 40, 50) <class 'tuple'> 1925050943344
# (10, 20, 30, 40, 50) <class 'tuple'> 1925050945104

# %% [markdown]
# #### **Mutable**
# * *Same data stores in Different location*
# * *Different Data stores in Different location*

# %%
x = [10,20,30,40,50]
y = [10,20,30,40,50]
print(x,type(x),id(x))
print(y,type(y),id(y))
# Out:
# [10, 20, 30, 40, 50] <class 'list'> 1925036515328
# [10, 20, 30, 40, 50] <class 'list'> 1925036515520

# %%
a = 100
b = 100
print(a != b) 
print(a is not b)
# Out:
# False
# False

# %%
x = (10,20,30,40,50)
y = (10,20,30,40,50)
print(x != y)
print( x is y)
# Out:
# False
# False
